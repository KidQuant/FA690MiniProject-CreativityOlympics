# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('resume_output.csv')

# %%
df.description[0]
# Out:
# "Quantitative Researcher - Execution\n\nAn opportunity within a tier one hedge fund to join a global team specializing in all aspects of quantitative research for fundamental equity execution strategies. The team is responsible for developing and optimizing algorithmic strategies for electronic execution of equity markets.\n\nAs a Quantitative Researcher, the successful candidate will have with a strong background in developing execution trading algorithms with a deep understanding of trading dynamics, quantitative modeling, and algorithmic strategy development, with expertise equity markets.\n\nKey Responsibilities:\n• Design, develop, and optimize execution trading algorithms for equity markets.\n• Analyze market microstructure in equity markets, understanding order placement methodologies, routing, market impact, and transaction cost analysis.\n• Conduct research to identify market signals that can enhance trading strategies and improve execution.\n• Build and implement advanced q
# ...
